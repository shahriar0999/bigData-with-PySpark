# %% [markdown]
# # READ SINGLE LINE JSON

# %%
df=spark.read.json("/Volumes/readcsv/mylocal_csv_file/local_to_cloud/dataJSON/sales_single_line.json")
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# # READ MULTILINE JSON

# %%
df=spark.read.option("multiline","true").json("/Volumes/readcsv/mylocal_csv_file/local_to_cloud/dataJSON/sales_multi_line.json")
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# # SAVE THE JSON FILE INTO JSON/CSV FORMAT

# %%
# COMMAND ----------

df.write.format("csv").save("/Volumes/readcsv/mylocal_csv_file/local_to_cloud/json_2_csv")

# %% [markdown]
# # PARQUET DATA

# %%
# Databricks notebook source
df=spark.read.json("/Volumes/readcsv/mylocal_csv_file/local_to_cloud/dataJSON/sales_single_line.json")
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.write.format("parquet").save("/Volumes/readcsv/mylocal_csv_file/local_to_cloud/parquet_files")

# %%
df2=spark.read.format("parquet").load("/Volumes/readcsv/mylocal_csv_file/local_to_cloud/parquet_files")

# COMMAND ----------

display(df2)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
